# %% [markdown]
# #### Text Splitting from Documents- RecursiveCharacter Text Splitters
# This text splitter is the recommended one for generic text. It is parameterized by a list of characters. It tries to split on them in order until the chunks are small enough. The default list is ["\n\n", "\n", " ", ""]. This has the effect of trying to keep all paragraphs (and then sentences, and then words) together as long as possible, as those would generically seem to be the strongest semantically related pieces of text.
#
# - How the text is split: by list of characters.
# - How the chunk size is measured: by number of characters.

# %%
from langchain_community.document_loaders import PyPDFLoader
loader=PyPDFLoader('ros2.pdf')
docs=loader.load()
docs
# Out:
# [Document(metadata={'producer': 'macOS 版本 10.14.6（版号 18G103） Quartz PDFContext', 'creator': 'Word', 'creationdate': '2020-04-30T05:43:24+00:00', 'aapl:keywords': '[]', 'keywords': '', 'moddate': '2020-05-12T10:00:27+02:00', 'title': 'Microsoft Word - SAS_Blog_Mar_ESR2_LIAO_Yuan_v3_1703_vOD-1.docx', 'source': 'ros2.pdf', 'total_pages': 5, 'page': 0, 'page_label': '1'}, page_content='Introduction of Robot Operating System 2: ROS2 -- H2020-MSCA-ITN SAS Program - ESR2 - LIAO Yuan In autonomous driving, the increasing complexity of systems poses great changes in maintaining dependability for lifecycle of software engineering. Among them, middleware [1] is one of the most challengeable research parts for overall systems. The middleware challenges are involved in: capabilities of runtime adaptation to applications, communication between heterogeneous systems in different levels of middleware [1], runtime safety assurance under failure circumstances, and others. In this article, I introduce 
# ...

# %%
type(docs[0])
# Out:
# langchain_core.documents.base.Document

# %% [markdown]
# ##### How to recursively split text by characters

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter=RecursiveCharacterTextSplitter(chunk_size=500,chunk_overlap=50)
final_documents=text_splitter.split_documents(docs) #we used split documents because we are passing a list of documents
final_documents
# Out:
# [Document(metadata={'producer': 'macOS 版本 10.14.6（版号 18G103） Quartz PDFContext', 'creator': 'Word', 'creationdate': '2020-04-30T05:43:24+00:00', 'aapl:keywords': '[]', 'keywords': '', 'moddate': '2020-05-12T10:00:27+02:00', 'title': 'Microsoft Word - SAS_Blog_Mar_ESR2_LIAO_Yuan_v3_1703_vOD-1.docx', 'source': 'ros2.pdf', 'total_pages': 5, 'page': 0, 'page_label': '1'}, page_content='Introduction of Robot Operating System 2: ROS2 -- H2020-MSCA-ITN SAS Program - ESR2 - LIAO Yuan In autonomous driving, the increasing complexity of systems poses great changes in maintaining dependability for lifecycle of software engineering. Among them, middleware [1] is one of the most challengeable research parts for overall systems. The middleware challenges are involved in: capabilities of runtime adaptation to applications, communication between heterogeneous systems in different levels'),
# ...

# %%
print(final_documents[0])
print(final_documents[1])
# Out:
# page_content='Introduction of Robot Operating System 2: ROS2 -- H2020-MSCA-ITN SAS Program - ESR2 - LIAO Yuan In autonomous driving, the increasing complexity of systems poses great changes in maintaining dependability for lifecycle of software engineering. Among them, middleware [1] is one of the most challengeable research parts for overall systems. The middleware challenges are involved in: capabilities of runtime adaptation to applications, communication between heterogeneous systems in different levels' metadata={'producer': 'macOS 版本 10.14.6（版号 18G103） Quartz PDFContext', 'creator': 'Word', 'creationdate': '2020-04-30T05:43:24+00:00', 'aapl:keywords': '[]', 'keywords': '', 'moddate': '2020-05-12T10:00:27+02:00', 'title': 'Microsoft Word - SAS_Blog_Mar_ESR2_LIAO_Yuan_v3_1703_vOD-1.docx', 'source': 'ros2.pdf', 'total_pages': 5, 'page': 0, 'page_label': '1'}
# ...

# %%
## Text Loader

from langchain_community.document_loaders import TextLoader

loader=TextLoader('example.txt')
docs=loader.load()
docs
# Out:
# [Document(metadata={'source': 'example.txt'}, page_content='India, officially the Republic of India, is a country in South Asia. It is the seventh-largest country by area; the most populous country since 2023; and, since its independence in 1947, the world\'s most populous democracy.\n\nIndia\'s "best friends" or closest strategic partners are generally identified as Russia, Israel, Japan, France, and Bhutan due to long-term trust, defense cooperation, and diplomatic support. These nations are characterized by consistent, reliable partnerships, often described as "time-tested" or "strategic," rather than solely based on transactional interests\n\nIndia is currently grappling with a surge of influenza infections, predominantly caused by a virulent strain known as H3N2. Given how quickly this viral outbreak spreads, people must recognise its prevalence rate and take the appropriate safety measures.')]

# %%
speech=""
with open("example.txt") as f:
    speech=f.read()

text_splitter=RecursiveCharacterTextSplitter(chunk_size=100,chunk_overlap=20)
text=text_splitter.create_documents([speech]) #we used create documents because we are passing a list of strings
print(text[0])
print(text[1])
# Out:
# page_content='India, officially the Republic of India, is a country in South Asia. It is the seventh-largest'
# page_content='the seventh-largest country by area; the most populous country since 2023; and, since its'

# %%
#Finally this is how you can use the text splitter with the text loader in one go
#these are used when you have a large text file and you want to split it into smaller chunks for processing.
#splitting is important because it allows you to work with smaller pieces of text, which can be more manageable and efficient for various natural language processing tasks.
